# %% [markdown]
# # シンプルテスト

# %%
import msal
import requests

TENANT_ID = "58970528-d083-476f-9082-2d21bd11a800"
CLIENT_ID = "99a8342c-e187-44bd-a6d6-3c9ad5ffd0f0"

# Scopes must match the delegated permissions you added in Entra ID
SCOPES = [
    "Calendars.Read",
    "Chat.Read",
    "OnlineMeetings.Read",
    "OnlineMeetingTranscript.Read.All",
    "Team.ReadBasic.All",
    "Channel.ReadBasic.All",
    "ChannelMessage.Read.All",
    "User.Read",
]

AUTHORITY = f"https://login.microsoftonline.com/{TENANT_ID}"

app = msal.PublicClientApplication(
    client_id=CLIENT_ID,
    authority=AUTHORITY,)

flow = app.initiate_device_flow(scopes=SCOPES)
if "user_code" not in flow:
    raise RuntimeError(f"Failed to create device flow: {flow}")

print(flow["message"])  # User instructions

result = app.acquire_token_by_device_flow(flow)

if "access_token" not in result:
    raise RuntimeError(f"Failed to acquire token: {result}")

access_token = result["access_token"]

headers = {"Authorization": f"Bearer {access_token}"}

# Example 1: List chats the user is in
r = requests.get("https://graph.microsoft.com/v1.0/me/chats", headers=headers)
print("me/chats:", r.status_code)
print(r.text)

# Example 2: Joined teams
r = requests.get("https://graph.microsoft.com/v1.0/me/joinedTeams", headers=headers)
print("me/joinedTeams:", r.status_code)
print(r.text)
# Out:
# To sign in, use a web browser to open the page https://microsoft.com/devicelogin and enter the code AM4WYUJNQ to authenticate.
# me/chats: 200
# {"@odata.context":"https://graph.microsoft.com/v1.0/$metadata#chats","@odata.count":8,"value":[{"id":"19:83b23399b2f94e90a771c8c5fe262fa5@thread.v2","topic":null,"createdDateTime":"2026-01-29T06:10:00Z","lastUpdatedDateTime":"2026-01-29T06:10:00.513Z","chatType":"group","webUrl":"https://teams.microsoft.com/l/chat/19%3A83b23399b2f94e90a771c8c5fe262fa5%40thread.v2/0?tenantId=58970528-d083-476f-9082-2d21bd11a800","tenantId":"58970528-d083-476f-9082-2d21bd11a800","isHiddenForAllMembers":false,"onlineMeetingInfo":null,"viewpoint":{"isHidden":false,"lastMessageReadDateTime":"2026-01-29T06:44:06.78Z"}},{"id":"19:a0576424-04db-4808-88d9-4cfaa09b02c6_a52ac978-0df2-4e13-91e9-a1571eecde73@unq.gbl.spaces","topic":null,"createdDateTime":"2026-01-29T06:08:57Z","lastUpdatedDateTime":"2026-01-29T06:08:57.138Z","chatType":"oneOnOne","webUrl":"https://teams.microsoft.com/l/chat/19%3Aa0576424-04db-4808-88d9-4cfaa09b02c6_a52ac978-0df2-4e13-91e9-a1571eecde73%40unq.gbl.spaces/0?tenantId=58970528-d083-476f-9082-2d21bd11a800","tenantId":"58970528-d083-476f-9082-2d21bd11a800","isHiddenForAllMembers":false,"onlineMeetingInfo":null,"viewpoint":{"isHidden":false,"lastMessageReadDateTime":"0001-01-01T00:00:00Z"}},{"id":"19:meeting_YzkyZGE0NmItN2Y4Zi00NmJkLTgxYzktZDlmZGY3OTM2MGRm@thread.v2","topic":"定例会議","createdDateTime":"2026-01-05T02:42:32.679Z","lastUpdatedDateTime":"2026-01-05T02:48:42.005Z","chatType":"meeting","webUrl":"https://teams.microsoft.com/l/chat/19%3Ameeting_YzkyZGE0NmItN2Y4Zi00NmJkLTgxYzktZDlmZGY3OTM2MGRm%40thread.v2/0?tenantId=58970528-d083-476f-9082-2d21bd11a800","tenantId":"58970528-d083-476f-9082-2d21bd11a800","isHiddenForAllMembers":false,"viewpoint":{"isHidden":false,"lastMessageReadDateTime":"0001-01-01T00:00:00Z"},"onlineMeetingInfo":{"calendarEventId":null,"joinWebUrl":"https://teams.microsoft.com/l/meetup-join/19%3ameeting_YzkyZGE0NmItN2Y4Zi00NmJkLTgxYzktZDlmZGY3OTM2MGRm%40thread.v2/0?context=%7b%22Tid%22%3a%2258970528-d083-476f-9082-2d21bd11a800%22%2c%22Oid%22%3a%22a52ac978-0df2-4e13-91e9-a1571eecde73%22%7d","organizer":{"id":"a52ac978-0df2-4e13-91e9-a1571eecde73","displayName":null,"userIdentityType":"aadUser"}}},{"id":"19:a52ac978-0df2-4e13-91e9-a1571eecde73_34fe9e6b-6b50-4370-95ff-75251df9f101@unq.gbl.spaces","topic":null,"createdDateTime":"2025-11-30T23:22:25.205Z","lastUpdatedDateTime":"2025-11-30T23:22:25.681Z","chatType":"oneOnOne","webUrl":"https://teams.microsoft.com/l/chat/19%3Aa52ac978-0df2-4e13-91e9-a1571eecde73_34fe9e6b-6b50-4370-95ff-75251df9f101%40unq.gbl.spaces/0?tenantId=58970528-d083-476f-9082-2d21bd11a800","tenantId":"58970528-d083-476f-9082-2d21bd11a800","isHiddenForAllMembers":false,"onlineMeetingInfo":null,"viewpoint":{"isHidden":false,"lastMessageReadDateTime":"0001-01-01T00:00:00Z"}},{"id":"19:a52ac978-0df2-4e13-91e9-a1571eecde73_cb603fb1-f4f8-465e-9694-a868affbe8de@unq.gbl.spaces","topic":null,"createdDateTime":"2025-11-26T16:29:53.845Z","lastUpdatedDateTime":"2025-11-26T16:29:54.231Z","chatType":"oneOnOne","webUrl":"https://teams.microsoft.com/l/chat/19%3Aa52ac978-0df2-4e13-91e9-a1571eecde73_cb603fb1-f4f8-465e-9694-a868affbe8de%40unq.gbl.spaces/0?tenantId=58970528-d083-476f-9082-2d21bd11a800","tenantId":"58970528-d083-476f-9082-2d21bd11a800","isHiddenForAllMembers":false,"onlineMeetingInfo":null,"viewpoint":{"isHidden":false,"lastMessageReadDateTime":"0001-01-01T00:00:00Z"}},{"id":"19:a52ac978-0df2-4e13-91e9-a1571eecde73_bc34b4fd-783c-4525-aa1d-77d02a42dba6@unq.gbl.spaces","topic":null,"createdDateTime":"2025-11-25T14:34:03.239Z","lastUpdatedDateTime":"2025-11-25T14:34:03.675Z","chatType":"oneOnOne","webUrl":"https://teams.microsoft.com/l/chat/19%3Aa52ac978-0df2-4e13-91e9-a1571eecde73_bc34b4fd-783c-4525-aa1d-77d02a42dba6%40unq.gbl.spaces/0?tenantId=58970528-d083-476f-9082-2d21bd11a800","tenantId":"58970528-d083-476f-9082-2d21bd11a800","isHiddenForAllMembers":false,"onlineMeetingInfo":null,"viewpoint":{"isHidden":false,"lastMessageReadDateTime":"0001-01-01T00:00:00Z"}},{"id":"19:a52ac978-0df2-4e13-91e9 ...
# me/joinedTeams: 200
# {"@odata.context":"https://graph.microsoft.com/v1.0/$metadata#teams","@odata.count":1,"value":[{"id":"a7c4b767-03be-4974-9230-4d62ec88ccb2","createdDateTime":null,"displayName":"contoso_policy","description":"demo: contoso用の社内ポリシー共有チーム","internalId":null,"classification":null,"specialization":null,"visibility":null,"webUrl":null,"isArchived":false,"tenantId":"58970528-d083-476f-9082-2d21bd11a800","isMembershipLimitedToOwners":null,"memberSettings":null,"guestSettings":null,"messagingSettings":null,"funSettings":null,"discoverySettings":null,"tagSettings":null,"summary":null}]}

# %% [markdown]
# # Teams チャネル/グループチャット/会議データの取得
#
# このセクションでは、すでに取得済みの `access_token` / `headers` を使って、次の情報を取得するコードを追加します。
#
#
#
# - 特定チーム配下のチャネル一覧とチャネル ID 取得
#
# - グループチャット & 会議チャットの ID 取得
#
# - 特定チャネルの全メッセージ（＋必要であればスレッド返信）
#
# - 特定グループチャットの全メッセージ
#
# - ユーザーが主催/参加しているオンライン会議のメタデータ & 参加者
#
# - 会議トランスクリプト一覧 & コンテンツ取得（権限がある場合）
#
# - 会議に紐づくチャット（chatType = `meeting`）のメッセージ取得
#
#
#
# ※ 実際に API を呼び出すには、Microsoft Graph 側で必要な権限が付与されている必要があります。権限不足の場合は 403 などのエラーになります。

# %%
import json

from typing import List, Dict, Any



# 共通: @odata.nextLink をたどって全件取得するヘルパー

def get_with_paging(url: str, headers: Dict[str, str], params: Dict[str, Any] | None = None) -> List[Dict[str, Any]]:

    items: List[Dict[str, Any]] = []

    while url:

        print(f"GET {url}")

        resp = requests.get(url, headers=headers, params=params)

        print("  ->", resp.status_code)
        print(resp.text)

        resp.raise_for_status()

        data = resp.json()

        items.extend(data.get("value", []))

        # 次ページがある場合は @odata.nextLink に URL が入る

        url = data.get("@odata.nextLink")

        # 2 ページ目以降は params は不要

        params = None

    return items



# 1. チーム一覧 & 各チーム配下のチャネル一覧を取得して ID を確認

teams_url = "https://graph.microsoft.com/v1.0/me/joinedTeams"

teams = get_with_paging(teams_url, headers)



print("==== Joined Teams ====")

for t in teams:

    print(f"Team: {t.get('displayName')} | id={t.get('id')}")



print("\n==== Channels per Team ====")

for t in teams:

    team_id = t.get("id")

    channels_url = f"https://graph.microsoft.com/v1.0/teams/{team_id}/channels"

    channels = get_with_paging(channels_url, headers)

    print(f"\nTeam: {t.get('displayName')} ({team_id})")

    for ch in channels:

        print(f"  Channel: {ch.get('displayName')} | id={ch.get('id')}")



# 2. グループチャット & 会議チャットの ID 一覧

#   chatType: 'oneOnOne' | 'group' | 'meeting'

group_chats_url = "https://graph.microsoft.com/v1.0/me/chats?$filter=chatType eq 'group'"

group_chats = get_with_paging(group_chats_url, headers)



print("\n==== Group Chats (chatType = group) ====")

for chat in group_chats:

    print(f"Group Chat: {chat.get('topic')} | id={chat.get('id')} | lastMessagePreview={chat.get('lastMessagePreview', {}).get('body', {}).get('content')}")



meeting_chats_url = "https://graph.microsoft.com/v1.0/me/chats?$filter=chatType eq 'meeting'"

meeting_chats = get_with_paging(meeting_chats_url, headers)



print("\n==== Meeting Chats (chatType = meeting) ====")

for chat in meeting_chats:

    # onlineMeetingInfo や topic からどの会議かを識別できます

    print("Meeting Chat:")

    print("  id=", chat.get("id"))

    print("  topic=", chat.get("topic"))

    print("  onlineMeetingInfo=", json.dumps(chat.get("onlineMeetingInfo"), ensure_ascii=False))

    print()
# Out:
# GET https://graph.microsoft.com/v1.0/me/joinedTeams
#   -> 200
# {"@odata.context":"https://graph.microsoft.com/v1.0/$metadata#teams","@odata.count":1,"value":[{"id":"a7c4b767-03be-4974-9230-4d62ec88ccb2","createdDateTime":null,"displayName":"contoso_policy","description":"demo: contoso用の社内ポリシー共有チーム","internalId":null,"classification":null,"specialization":null,"visibility":null,"webUrl":null,"isArchived":false,"tenantId":"58970528-d083-476f-9082-2d21bd11a800","isMembershipLimitedToOwners":null,"memberSettings":null,"guestSettings":null,"messagingSettings":null,"funSettings":null,"discoverySettings":null,"tagSettings":null,"summary":null}]}
# ==== Joined Teams ====
# Team: contoso_policy | id=a7c4b767-03be-4974-9230-4d62ec88ccb2
#
# ==== Channels per Team ====
# GET https://graph.microsoft.com/v1.0/teams/a7c4b767-03be-4974-9230-4d62ec88ccb2/channels
#   -> 200
# {"@odata.context":"https://graph.microsoft.com/v1.0/$metadata#teams('a7c4b767-03be-4974-9230-4d62ec88ccb2')/channels","@odata.count":2,"value":[{"id":"19:8zjMe4C0P-zr7EqzETew2ebgu1c6w6bNX-HVQ8Mmovc1@thread.tacv2","createdDateTime":"2025-11-23T05:57:35.352Z","displayName":"General","description":"demo: contoso用の社内ポリシー共有チーム","isFavoriteByDefault":null,"email":"contoso_policy@MngEnvMCAP873995.onmicrosoft.com","tenantId":"58970528-d083-476f-9082-2d21bd11a800","webUrl":"https://teams.cloud.microsoft/l/channel/19%3A8zjMe4C0P-zr7EqzETew2ebgu1c6w6bNX-HVQ8Mmovc1%40thread.tacv2/contoso_policy?groupId=a7c4b767-03be-4974-9230-4d62ec88ccb2&tenantId=58970528-d083-476f-9082-2d21bd11a800&allowXTenantAccess=True&ngc=True","membershipType":"standard","isArchived":false},{"id":"19:i_FuACGvIyZZzlPSCA-QURZQwtYW14ajQZL6nSPwzjQ1@thread.tacv2","createdDateTime":"2026-01-29T03:44:43.397Z","displayName":"管理職のみ","description":null,"isFavoriteByDefault":null,"email":null,"tenantId":"58970528-d083-476f-9082-2d21bd11a800","webUrl":"https://teams.cloud.microsoft/l/channel/19%3Ai_FuACGvIyZZzlPSCA-QURZQwtYW14ajQZL6nSPwzjQ1%40thread.tacv2/%E7%AE%A1%E7%90%86%E8%81%B7%E3%81%AE%E3%81%BF?groupId=a7c4b767-03be-4974-9230-4d62ec88ccb2&tenantId=58970528-d083-476f-9082-2d21bd11a800&allowXTenantAccess=True&ngc=True","membershipType":"unknownFutureValue","isArchived":false}]}
#
# Team: contoso_policy (a7c4b767-03be-4974-9230-4d62ec88ccb2)
#   Channel: General | id=19:8zjMe4C0P-zr7EqzETew2ebgu1c6w6bNX-HVQ8Mmovc1@thread.tacv2
#   Channel: 管理職のみ | id=19:i_FuACGvIyZZzlPSCA-QURZQwtYW14ajQZL6nSPwzjQ1@thread.tacv2
# GET https://graph.microsoft.com/v1.0/me/chats?$filter=chatType eq 'group'
#   -> 200
# {"@odata.context":"https://graph.microsoft.com/v1.0/$metadata#chats","@odata.count":1,"value":[{"id":"19:83b23399b2f94e90a771c8c5fe262fa5@thread.v2","topic":null,"createdDateTime":"2026-01-29T06:10:00Z","lastUpdatedDateTime":"2026-01-29T06:10:00.513Z","chatType":"group","webUrl":"https://teams.microsoft.com/l/chat/19%3A83b23399b2f94e90a771c8c5fe262fa5%40thread.v2/0?tenantId=58970528-d083-476f-9082-2d21bd11a800","tenantId":"58970528-d083-476f-9082-2d21bd11a800","isHiddenForAllMembers":false,"onlineMeetingInfo":null,"viewpoint":{"isHidden":false,"lastMessageReadDateTime":"2026-01-29T06:44:06.78Z"}}]}
#
# ==== Group Chats (chatType = group) ====
# Group Chat: None | id=19:83b23399b2f94e90a771c8c5fe262fa5@thread.v2 | lastMessagePreview=None
# GET https://graph.microsoft.com/v1.0/me/chats?$filter=chatType eq 'meeting'
#   -> 200
# {"@odata.context":"https://graph.microsoft.com/v1.0/$metadata#chats","@odata.count":1,"value":[{"id":"19:meeting_YzkyZGE0NmItN2Y4Zi00NmJkLTgxYzktZDlmZGY3OTM2MGRm@thread.v2","topic":"定例会議","createdDateTime":"2026-01-05T02:42:32.679Z","lastUpdatedDateTime":"2026-01-05T02:48:42.005Z","chatType":"meeting","webUrl":"https://teams.microsoft.com/l/chat/19%3Ameeting_YzkyZGE0NmItN2Y4Zi00NmJkLTgxYzktZDlmZGY3OTM2MGRm%40thread.v2/0?tenantId=58970528-d083-476f-9082-2d21bd11a800","tenantId":"58970528-d083-476f-9082-2d21bd11a800","isHiddenForAllMembers":false,"viewpoint":{"isHidden":false,"lastMessageReadDateTime":"0001-01-01T00:00:00Z"},"onlineMeetingInfo":{"calendarEventId":null,"joinWebUrl":"https://teams.microsoft.com/l/meetup-join/19%3ameeting_YzkyZGE0NmItN2Y4Zi00NmJkLTgxYzktZDlmZGY3OTM2MGRm%40thread.v2/0?context=%7b%22Tid%22%3a%2258970528-d083-476f-9082-2d21bd11a800%22%2c%22Oid%22%3a%22a52ac978-0df2-4e13-91e9-a1571eecde73%22%7d","organizer":{"id":"a52ac978-0df2-4e13-91e9-a1571eecde73","displayName":null,"userIdentityType":"aadUser"}}}]}
#
# ==== Meeting Chats (chatType = meeting) ====
# Meeting Chat:
#   id= 19:meeting_YzkyZGE0NmItN2Y4Zi00NmJkLTgxYzktZDlmZGY3OTM2MGRm@thread.v2
#   topic= 定例会議
#   onlineMeetingInfo= {"calendarEventId": null, "joinWebUrl": "https://teams.microsoft.com/l/meetup-join/19%3ameeting_YzkyZGE0NmItN2Y4Zi00NmJkLTgxYzktZDlmZGY3OTM2MGRm%40thread.v2/0?context=%7b%22Tid%22%3a%2258970528-d083-476f-9082-2d21bd11a800%22%2c%22Oid%22%3a%22a52ac978-0df2-4e13-91e9-a1571eecde73%22%7d", "organizer": {"id": "a52ac978-0df2-4e13-91e9-a1571eecde73", "displayName": null, "userIdentityType": "aadUser"}}

# %% [markdown]
# ## 特定チャネルの全メッセージ取得
#
# 上のセルで確認した `team_id` と `channel_id` を使って、特定チャネルの全メッセージ（＋必要に応じて返信）を取得します。
#
#
#
# - メッセージ本体: `/teams/{team-id}/channels/{channel-id}/messages`
#
# - 各メッセージの返信: `/teams/{team-id}/channels/{channel-id}/messages/{message-id}/replies`
#
#
#
# 取得したメッセージは Python のリストとして返すので、後続で pandas に流し込んだり、ファイル保存したりできます。

# %%
from datetime import datetime



def get_channel_messages(team_id: str, channel_id: str) -> List[Dict[str, Any]]:

    """特定チャネルの全メッセージを取得"""

    url = f"https://graph.microsoft.com/v1.0/teams/{team_id}/channels/{channel_id}/messages"

    return get_with_paging(url, headers)



def get_channel_message_replies(team_id: str, channel_id: str, message_id: str) -> List[Dict[str, Any]]:

    """特定メッセージのスレッド返信を全件取得"""

    url = f"https://graph.microsoft.com/v1.0/teams/{team_id}/channels/{channel_id}/messages/{message_id}/replies"

    return get_with_paging(url, headers)



# 使い方例: team_id / channel_id は上のセルの出力からコピペ

# team_id = "<チームID>"

# channel_id = "<チャネルID>"

# messages = get_channel_messages(team_id, channel_id)

# print(len(messages), "messages")

# 先頭 3 件をタイトル＋送信者＋送信日時だけ表示

# for m in messages[:3]:

#     from_user = (m.get("from", {}) or {}).get("user", {}) or {}

#     user_name = from_user.get("displayName")

#     created = m.get("createdDateTime")

#     print(created, "|", user_name, "|", (m.get("body", {}) or {}).get("content"))

# %%
# 使い方例: team_id / channel_id は上のセルの出力からコピペ

team_id = "a7c4b767-03be-4974-9230-4d62ec88ccb2"

channel_id = "19:8zjMe4C0P-zr7EqzETew2ebgu1c6w6bNX-HVQ8Mmovc1@thread.tacv2"

messages = get_channel_messages(team_id, channel_id)

print(len(messages), "messages")

# 先頭 3 件をタイトル＋送信者＋送信日時だけ表示

for m in messages:

    from_user = (m.get("from", {}) or {}).get("user", {}) or {}

    user_name = from_user.get("displayName")

    created = m.get("createdDateTime")

    print(created, "|", user_name, "|", (m.get("body", {}) or {}).get("content"))
# Out:
# GET https://graph.microsoft.com/v1.0/teams/a7c4b767-03be-4974-9230-4d62ec88ccb2/channels/19:8zjMe4C0P-zr7EqzETew2ebgu1c6w6bNX-HVQ8Mmovc1@thread.tacv2/messages
#   -> 200
# {"@odata.context":"https://graph.microsoft.com/v1.0/$metadata#teams('a7c4b767-03be-4974-9230-4d62ec88ccb2')/channels('19%3A8zjMe4C0P-zr7EqzETew2ebgu1c6w6bNX-HVQ8Mmovc1%40thread.tacv2')/messages","@odata.count":16,"value":[{"id":"1767581607302","replyToId":null,"etag":"1769660632981","messageType":"message","createdDateTime":"2026-01-05T02:53:27.302Z","lastModifiedDateTime":"2026-01-29T04:23:52.981Z","lastEditedDateTime":null,"deletedDateTime":null,"subject":null,"summary":null,"chatId":null,"importance":"normal","locale":"en-us","webUrl":"https://teams.microsoft.com/l/message/19%3A8zjMe4C0P-zr7EqzETew2ebgu1c6w6bNX-HVQ8Mmovc1%40thread.tacv2/1767581607302?groupId=a7c4b767-03be-4974-9230-4d62ec88ccb2&tenantId=58970528-d083-476f-9082-2d21bd11a800&createdTime=1767581607302&parentMessageId=1767581607302","policyViolation":null,"eventDetail":null,"from":{"application":null,"device":null,"user":{"@odata.type":"#microsoft.graph.teamworkUserIdentity","id":"a52ac978-0df2-4e13-91e9-a1571eecde73","displayName":null,"userIdentityType":"aadUser","tenantId":"58970528-d083-476f-9082-2d21bd11a800"}},"body":{"contentType":"html","content":"会議を予定<attachment id=\"1767581676818\"></attachment>"},"channelIdentity":{"teamId":"a7c4b767-03be-4974-9230-4d62ec88ccb2","channelId":"19:8zjMe4C0P-zr7EqzETew2ebgu1c6w6bNX-HVQ8Mmovc1@thread.tacv2"},"attachments":[{"id":"1767581676818","contentType":"meetingReference","contentUrl":null,"content":"{\"exchangeId\":\"AAMkADg3ZTRlZThjLTYxY2YtNGM3Ny1iMzBiLWE0MzRiYTliM2VkOABGAAAAAAC1qlmSAw8mToExpTSayrmhBwAszWQ9kmQtT5DmDiqLugdHAAAAAAENAAAszWQ9kmQtT5DmDiqLugdHAAAYHq8fAAA=\",\"organizerId\":\"a52ac978-0df2-4e13-91e9-a1571eecde73\",\"meetingJoinUrl\":\"https://teams.microsoft.com/l/meetup-join/19%3a8zjMe4C0P-zr7EqzETew2ebgu1c6w6bNX-HVQ8Mmovc1%40thread.tacv2/1767581607302?context=%7b%22Tid%22%3a%2258970528-d083-476f-9082-2d21bd11a800%22%2c%22Oid%22%3a%22a52ac978-0df2-4e13-91e9-a1571eecde73%22%7d\"}","name":"定例","thumbnailUrl":null,"teamsAppId":null}],"mentions":[],"reactions":[]},{"id":"1769660660856","replyToId":null,"etag":"1769660662315","messageType":"unknownFutureValue","createdDateTime":"2026-01-29T04:24:20.856Z","lastModifiedDateTime":"2026-01-29T04:24:22.315Z","lastEditedDateTime":null,"deletedDateTime":null,"subject":null,"summary":null,"chatId":null,"importance":"normal","locale":"en-us","webUrl":"https://teams.microsoft.com/l/message/19%3A8zjMe4C0P-zr7EqzETew2ebgu1c6w6bNX-HVQ8Mmovc1%40thread.tacv2/1769660660856?groupId=a7c4b767-03be-4974-9230-4d62ec88ccb2&tenantId=58970528-d083-476f-9082-2d21bd11a800&createdTime=1769660660856&parentMessageId=1769660660856","from":null,"policyViolation":null,"body":{"contentType":"html","content":"<systemEventMessage/>"},"channelIdentity":{"teamId":"a7c4b767-03be-4974-9230-4d62ec88ccb2","channelId":"19:8zjMe4C0P-zr7EqzETew2ebgu1c6w6bNX-HVQ8Mmovc1@thread.tacv2"},"attachments":[],"mentions":[],"reactions":[],"eventDetail":{"@odata.type":"#microsoft.graph.callRecordingEventMessageDetail","callId":"f6160547-7870-4d26-8a47-789954be1877","callRecordingDisplayName":"定例-20260129_042202UTC-Meeting Recording.mp4","callRecordingUrl":"https://mngenvmcap873995.sharepoint.com/sites/contoso_policy/Shared%20Documents/General/Recordings/%E5%AE%9A%E4%BE%8B-20260129_042202UTC-Meeting%20Recording.mp4?web=1","callRecordingDuration":"PT1M51.66S","callRecordingStatus":"success","meetingOrganizer":{"application":null,"device":null,"user":{"@odata.type":"#microsoft.graph.teamworkUserIdentity","id":"a52ac978-0df2-4e13-91e9-a1571eecde73","displayName":null,"userIdentityType":"aadUser","tenantId":"58970528-d083-476f-9082-2d21bd11a800"}},"initiator":{"application":null,"device":null,"user":{"@odata.type":"#microsoft.graph.teamworkUserIdentity","id":"a52ac978-0df2-4e13-91e9-a1571eecde73","displayName":null,"userIdentityType":"aadUser","tenantId":"58970528-d083-476f-9082-2d21bd11a800"}}}},{"id":"1769660635552","replyToId":null,"etag":"1769660635552","messageType":"unknownFutureValue","createdDateTime":"2026-01 ...
# 16 messages
# 2026-01-05T02:53:27.302Z | None | 会議を予定<attachment id="1767581676818"></attachment>
# 2026-01-29T04:24:20.856Z | None | <systemEventMessage/>
# 2026-01-29T04:23:55.552Z | None | <systemEventMessage/>
# 2026-01-29T04:22:08.048Z | None | <systemEventMessage/>
# 2026-01-29T03:46:51.344Z | Hiroaki Ishida | <p><at id="0">一般</at></p>
# <p>お疲れ様です。設計方針についての共有です。</p>
# <ul>
# <li>2026/1/28: 機能Aを最優先とする。</li></ul>
# 2026-01-29T04:07:51.052Z | None | <systemEventMessage/>
# 2026-01-11T06:58:48.195Z | None | <p>進捗レポートを改善する方法をいくつか紹介します:</p>
#
#
# <ul>
#
#
# <li>チャネルでその他のメッセージを送信します</li>
#
# <li>会議など、他の会話に私を追加してください</li>
# </ul>
# 2026-01-11T06:58:45.933Z | None | <p>進捗レポートの準備ができました。
# "Loop 段落を追加する" をクリックして、レポートを表示してください。</p>
# 2026-01-05T02:56:55.889Z | None | <systemEventMessage/>
# 2026-01-05T02:56:27.821Z | None | <systemEventMessage/>
# 2026-01-05T02:56:23.088Z | None | <systemEventMessage/>
# 2026-01-05T02:54:02.7Z | None | <systemEventMessage/>
# 2026-01-05T02:53:54.61Z | None | <systemEventMessage/>
# 2025-11-30T06:58:22.623Z | None | <p>みなさん、こんにちは。レポートを生成するのに十分なアクティビティがありませんでした。次回の予定時刻にもう一度確認します。</p>
# 2025-11-23T05:58:32.897Z | None | <p><strong>皆さん、こんにちは。私はこのチャネルに追加されました。</strong></p>
#
#
# <p>あなたが最優先事項に集中できるよう、私が日常的な作業を担当します。お手伝いできることは次のとおりです。</p>
#
#
# <ul>
#
#
# <li>更新内容、進行状況、障害を把握する<strong>状態レポートを作成します</strong>。</li>
#
# <li>作業を整理し、計画通りに進めるために<strong>タスクを追加して割り当てます</strong>。</li>
#
# <li>常に連携と調整を保つために<strong>会議をスケジュールします</strong>。</li>
#
# <li><strong>私が参加しているチャットや会議でこのチャネルから</strong>知識を共有します**。</li>
# </ul>
#
#
# <p>チャネルに関するトピックでサポートが必要な場合は、いつでも私に @メンションしてください。</p>
# 2025-11-23T05:58:30.073Z | None | <systemEventMessage/>

# %% [markdown]
# ## 特定グループチャットの全メッセージ取得
#
# グループチャット ID（上の `Group Chats` の一覧で表示される `id`）を指定して、そのチャットの全メッセージを取得します。
#
#
#
# - メッセージ本体: `/chats/{chat-id}/messages`
#
# - 1 対 1 チャットでもグループチャットでも同じエンドポイントで取得できます。
#
#
#
# ここでは主に `chatType = group` のチャットを想定しています。

# %%
def get_chat_messages(chat_id: str) -> List[Dict[str, Any]]:

    """特定チャット (1:1 / グループ / 会議チャット) の全メッセージを取得"""

    url = f"https://graph.microsoft.com/v1.0/chats/{chat_id}/messages"

    return get_with_paging(url, headers)



# 使い方例: group_chat_id は Group Chats の出力からコピペ

# group_chat_id = "<グループチャットID>"

# chat_messages = get_chat_messages(group_chat_id)

# print(len(chat_messages), "messages in group chat")

# for m in chat_messages[:3]:

#     from_user = (m.get("from", {}) or {}).get("user", {}) or {}

#     user_name = from_user.get("displayName")

#     created = m.get("createdDateTime")

#     print(created, "|", user_name, "|", (m.get("body", {}) or {}).get("content"))

# %%
# 使い方例: group_chat_id は Group Chats の出力からコピペ

group_chat_id = "19:83b23399b2f94e90a771c8c5fe262fa5@thread.v2"

chat_messages = get_chat_messages(group_chat_id)

print(len(chat_messages), "messages in group chat")

for m in chat_messages:

    from_user = (m.get("from", {}) or {}).get("user", {}) or {}

    user_name = from_user.get("displayName")

    created = m.get("createdDateTime")

    print(created, "|", user_name, "|", (m.get("body", {}) or {}).get("content"))
# Out:
# GET https://graph.microsoft.com/v1.0/chats/19:83b23399b2f94e90a771c8c5fe262fa5@thread.v2/messages
#   -> 200
# {"@odata.context":"https://graph.microsoft.com/v1.0/$metadata#chats('19%3A83b23399b2f94e90a771c8c5fe262fa5%40thread.v2')/messages","@odata.count":6,"value":[{"id":"1769669046780","replyToId":null,"etag":"1769669046780","messageType":"message","createdDateTime":"2026-01-29T06:44:06.78Z","lastModifiedDateTime":"2026-01-29T06:44:06.78Z","lastEditedDateTime":null,"deletedDateTime":null,"subject":null,"summary":null,"chatId":"19:83b23399b2f94e90a771c8c5fe262fa5@thread.v2","importance":"normal","locale":"en-us","webUrl":null,"channelIdentity":null,"policyViolation":null,"eventDetail":null,"from":{"application":null,"device":null,"user":{"@odata.type":"#microsoft.graph.teamworkUserIdentity","id":"a0576424-04db-4808-88d9-4cfaa09b02c6","displayName":"Hiroaki Ishida (IC)","userIdentityType":"aadUser","tenantId":"58970528-d083-476f-9082-2d21bd11a800"}},"body":{"contentType":"html","content":"<p>明日は会議よろしくお願いいたします。</p>"},"attachments":[],"mentions":[],"reactions":[]},{"id":"1769669043094","replyToId":null,"etag":"1769669043094","messageType":"message","createdDateTime":"2026-01-29T06:44:03.094Z","lastModifiedDateTime":"2026-01-29T06:44:03.094Z","lastEditedDateTime":null,"deletedDateTime":null,"subject":null,"summary":null,"chatId":"19:83b23399b2f94e90a771c8c5fe262fa5@thread.v2","importance":"normal","locale":"en-us","webUrl":null,"channelIdentity":null,"policyViolation":null,"eventDetail":null,"from":{"application":null,"device":null,"user":{"@odata.type":"#microsoft.graph.teamworkUserIdentity","id":"a0576424-04db-4808-88d9-4cfaa09b02c6","displayName":"Hiroaki Ishida (IC)","userIdentityType":"aadUser","tenantId":"58970528-d083-476f-9082-2d21bd11a800"}},"body":{"contentType":"html","content":"<p>案件Aについてはこちらでやりとりしましょう。</p>"},"attachments":[],"mentions":[],"reactions":[]},{"id":"1769669029188","replyToId":null,"etag":"1769669029188","messageType":"message","createdDateTime":"2026-01-29T06:43:49.188Z","lastModifiedDateTime":"2026-01-29T06:43:49.188Z","lastEditedDateTime":null,"deletedDateTime":null,"subject":null,"summary":null,"chatId":"19:83b23399b2f94e90a771c8c5fe262fa5@thread.v2","importance":"normal","locale":"en-us","webUrl":null,"channelIdentity":null,"policyViolation":null,"eventDetail":null,"from":{"application":null,"device":null,"user":{"@odata.type":"#microsoft.graph.teamworkUserIdentity","id":"a0576424-04db-4808-88d9-4cfaa09b02c6","displayName":"Hiroaki Ishida (IC)","userIdentityType":"aadUser","tenantId":"58970528-d083-476f-9082-2d21bd11a800"}},"body":{"contentType":"html","content":"<p>よろしくお願いいたします。</p>"},"attachments":[],"mentions":[],"reactions":[]},{"id":"1769669027092","replyToId":null,"etag":"1769669027092","messageType":"message","createdDateTime":"2026-01-29T06:43:47.092Z","lastModifiedDateTime":"2026-01-29T06:43:47.092Z","lastEditedDateTime":null,"deletedDateTime":null,"subject":null,"summary":null,"chatId":"19:83b23399b2f94e90a771c8c5fe262fa5@thread.v2","importance":"normal","locale":"en-us","webUrl":null,"channelIdentity":null,"policyViolation":null,"eventDetail":null,"from":{"application":null,"device":null,"user":{"@odata.type":"#microsoft.graph.teamworkUserIdentity","id":"a0576424-04db-4808-88d9-4cfaa09b02c6","displayName":"Hiroaki Ishida (IC)","userIdentityType":"aadUser","tenantId":"58970528-d083-476f-9082-2d21bd11a800"}},"body":{"contentType":"html","content":"<p>はい、</p>"},"attachments":[],"mentions":[],"reactions":[]},{"id":"1769667001195","replyToId":null,"etag":"1769667001195","messageType":"message","createdDateTime":"2026-01-29T06:10:01.195Z","lastModifiedDateTime":"2026-01-29T06:10:01.195Z","lastEditedDateTime":null,"deletedDateTime":null,"subject":null,"summary":null,"chatId":"19:83b23399b2f94e90a771c8c5fe262fa5@thread.v2","importance":"normal","locale":"en-us","webUrl":null,"channelIdentity":null,"policyViolation":null,"eventDetail":null,"from":{"application":null,"device":null,"user":{"@odata.type":"#microsoft.graph.teamworkUserIdentity","id":"a52ac978-0df2-4e13-91e9-a1571eecde73","displayName":"Hiroaki  ...
# 6 messages in group chat
# 2026-01-29T06:44:06.78Z | Hiroaki Ishida (IC) | <p>明日は会議よろしくお願いいたします。</p>
# 2026-01-29T06:44:03.094Z | Hiroaki Ishida (IC) | <p>案件Aについてはこちらでやりとりしましょう。</p>
# 2026-01-29T06:43:49.188Z | Hiroaki Ishida (IC) | <p>よろしくお願いいたします。</p>
# 2026-01-29T06:43:47.092Z | Hiroaki Ishida (IC) | <p>はい、</p>
# 2026-01-29T06:10:01.195Z | Hiroaki Ishida | <p>こんにちは</p>
# 2026-01-29T06:10:00.699Z | None | <systemEventMessage/>

# %% [markdown]
# ## オンライン会議のメタデータ・参加者・トランスクリプト・会議チャット
#
# オンライン会議まわりの情報取得は次のように行います。
#
#
#
# 1. `/me/onlineMeetings` でユーザーが主催/参加するオンライン会議一覧を取得
#
#     - `id`, `subject`, `startDateTime`, `endDateTime`, `joinWebUrl` などが含まれます
#
#     - `participants` の中に参加者情報があります
#
# 2. 特定会議に対して `/me/onlineMeetings/{meeting-id}/transcripts` でトランスクリプト一覧
#
#     - さらに `/me/onlineMeetings/{meeting-id}/transcripts/{transcript-id}/content` で実際のテキスト (通常は VTT) を取得
#
#     - これらの API はテナント側でトランスクリプト機能が有効 & 必要な Graph 権限が付与されている必要があります
#
# 3. 会議中チャットは、`chatType = 'meeting'` のチャットとして `/me/chats` から取得可能
#
#     - 上の「Meeting Chats」一覧の `id` を `get_chat_messages` に渡せば、その会議チャットの全メッセージを取得できます
#
#
#
# > 備考: トランスクリプト関連 API は組織全体/app 権限や RSC (resource-specific consent) 権限を前提としていることが多いため、
#
# > 単純なユーザー委任トークンだけだと 403 になる場合があります。その場合はテナント管理者に Graph 権限設定を相談してください。

# %%
from urllib.parse import quote

from datetime import datetime



def get_online_meeting_by_join_url(join_url: str) -> Dict[str, Any] | None:

    """joinWebUrl をキーに単一の onlineMeeting を取得



    /me/onlineMeetings は『一覧』ではなくフィルタ取得が基本で、

    例: GET /me/onlineMeetings?$filter=JoinWebUrl eq '{joinWebUrl}'



    join_url は Meeting チャットの onlineMeetingInfo や、

    カレンダー イベントの onlineMeeting プロパティから取得できます。

    """



    url = "https://graph.microsoft.com/v1.0/me/onlineMeetings"

    # requests に任せて $filter をクエリとして渡す

    flt = f"JoinWebUrl eq '{join_url}'"

    params = {"$filter": flt}



    print("GET", url, "? $filter=", flt)

    resp = requests.get(url, headers=headers, params=params)

    print("  ->", resp.status_code)

    print(resp.text)

    resp.raise_for_status()



    data = resp.json()

    meetings = data.get("value", []) or []

    if not meetings:

        print("No onlineMeeting found for this joinWebUrl")

        return None

    if len(meetings) > 1:

        print("Warning: multiple onlineMeetings returned. Using the first one.")

    return meetings[0]



def show_meeting_participants(meeting: Dict[str, Any]) -> None:

    """onlineMeeting オブジェクトから参加者情報をざっくり表示"""

    participants = meeting.get("participants", {}) or {}

    organizer = participants.get("organizer", {}) or {}

    attendees = participants.get("attendees", []) or []



    print("Organizer:")

    print("  ", (organizer.get("upn") or organizer.get("identity", {}).get("user", {}).get("displayName")))



    print("Attendees:")

    for a in attendees:

        identity = a.get("upn") or (a.get("identity", {}).get("user", {}) or {}).get("displayName")

        role = a.get("role")

        print("  ", identity, "| role=", role)



def list_meeting_transcripts(meeting_id: str) -> List[Dict[str, Any]]:

    """特定オンライン会議のトランスクリプト一覧を取得"""

    url = f"https://graph.microsoft.com/v1.0/me/onlineMeetings/{meeting_id}/transcripts"

    resp = requests.get(url, headers=headers)

    print("GET", url, "->", resp.status_code)

    print(resp.text)

    resp.raise_for_status()

    data = resp.json()

    transcripts = data.get("value", [])

    for t in transcripts:

        print("Transcript id=", t.get("id"), "| created=", t.get("createdDateTime"))

    return transcripts



def download_meeting_transcript_content_vtt(meeting_id: str, transcript_id: str, out_path: str) -> None:
    """
    onlineMeetings の transcript を VTT でダウンロードして保存
    """
    url = f"https://graph.microsoft.com/v1.0/me/onlineMeetings/{meeting_id}/transcripts/{transcript_id}/content"
    params = {"$format": "text/vtt"}

    hdrs = dict(headers)
    hdrs["Accept"] = "text/vtt"

    resp = requests.get(url, headers=hdrs, params=params)
    print("GET", resp.url, "->", resp.status_code)
    print(resp.text[:500])  # 失敗時の原因確認用（成功時はVTTの先頭が出る）

    resp.raise_for_status()

    # content はバイナリで返ることがあるので wb が安全
    with open(out_path, "wb") as f:
        f.write(resp.content)

    print("Saved transcript content to", out_path)



def download_meeting_transcript_content(meeting_id: str, transcript_id: str, out_path: str) -> None:

    """単一トランスクリプトの content を取得してファイル保存 (VTT など)

    NOTE: 一部テナント/エンドポイントでは /me パスで /content にアクセスすると 400 になるため、

          実運用では callTranscripts API (download_meeting_transcript_content_via_call_transcript) の利用を推奨します。"""

    url = f"https://graph.microsoft.com/v1.0/me/onlineMeetings/{meeting_id}/transcripts/{transcript_id}/content"

    resp = requests.get(url, headers=headers)

    print("GET", url, "->", resp.status_code)

    print(resp.text[:500])

    resp.raise_for_status()

    with open(out_path, "w", encoding="utf-8") as f:

        f.write(resp.text)

    print("Saved transcript content to", out_path)



def download_meeting_transcript_content_by_url(transcript_content_url: str, out_path: str) -> None:

    """transcriptContentUrl を使ってトランスクリプトの content を取得してファイル保存

    ※ このエンドポイントも環境によっては 400 になる場合があります。"""

    resp = requests.get(transcript_content_url, headers=headers)

    print("GET", transcript_content_url, "->", resp.status_code)

    print(resp.text[:500])

    resp.raise_for_status()

    with open(out_path, "w", encoding="utf-8") as f:

        f.write(resp.text)

    print("Saved transcript content to", out_path)



# 使い方例:

# 1. Meeting チャット一覧セルの出力から、対象会議の onlineMeetingInfo.joinWebUrl をコピペして join_url に入れる

#    （またはカレンダーイベントの onlineMeeting.joinUrl でも可）

# join_url = "<オンライン会議の joinWebUrl>"

# meeting = get_online_meeting_by_join_url(join_url)

# if meeting:

#     show_meeting_participants(meeting)

#     m_id = meeting.get("id")

#     transcripts = list_meeting_transcripts(m_id)

#     if transcripts:

#         t0_id = transcripts[0].get("id")

#         download_meeting_transcript_content_vtt(m_id, t0_id, "meeting_transcript_0.vtt")



# 会議中チャットのメッセージは、上の meeting_chats の出力から対象チャットの id を選び、

#   meeting_chat_id = "<Meeting Chat ID>"

#   meeting_chat_messages = get_chat_messages(meeting_chat_id)

# のように呼び出します。

# %%
# 使い方例:

# 1. meeting_chats 一覧セルを実行して、対象会議の onlineMeetingInfo を確認

# 2. その中の joinWebUrl を下の join_url にペースト



join_url = "https://teams.microsoft.com/l/meetup-join/19%3ameeting_YzkyZGE0NmItN2Y4Zi00NmJkLTgxYzktZDlmZGY3OTM2MGRm%40thread.v2/0?context=%7b%22Tid%22%3a%2258970528-d083-476f-9082-2d21bd11a800%22%2c%22Oid%22%3a%22a52ac978-0df2-4e13-91e9-a1571eecde73%22%7d"

meeting = get_online_meeting_by_join_url(join_url)

if meeting:

    show_meeting_participants(meeting)

    m_id = meeting.get("id")

    transcripts = list_meeting_transcripts(m_id)

    if transcripts:

        # transcripts[0]["id"] は callTranscript の ID として使える

        t0_id = transcripts[0].get("id")

        if t0_id:

            download_meeting_transcript_content_vtt(m_id, t0_id, "meeting_transcript_0.vtt")

        else:

            print("transcript id がレスポンスに含まれていません")



# 会議中チャットのメッセージは、上の meeting_chats の出力から対象チャットの id を選び、

meeting_chat_id = "19:meeting_YzkyZGE0NmItN2Y4Zi00NmJkLTgxYzktZDlmZGY3OTM2MGRm@thread.v2"

meeting_chat_messages = get_chat_messages(meeting_chat_id)

# のように呼び出します。
# Out:
# GET https://graph.microsoft.com/v1.0/me/onlineMeetings ? $filter= JoinWebUrl eq 'https://teams.microsoft.com/l/meetup-join/19%3ameeting_YzkyZGE0NmItN2Y4Zi00NmJkLTgxYzktZDlmZGY3OTM2MGRm%40thread.v2/0?context=%7b%22Tid%22%3a%2258970528-d083-476f-9082-2d21bd11a800%22%2c%22Oid%22%3a%22a52ac978-0df2-4e13-91e9-a1571eecde73%22%7d'
#   -> 200
# {"@odata.context":"https://graph.microsoft.com/v1.0/$metadata#users('a52ac978-0df2-4e13-91e9-a1571eecde73')/onlineMeetings","value":[{"id":"MSphNTJhYzk3OC0wZGYyLTRlMTMtOTFlOS1hMTU3MWVlY2RlNzMqMCoqMTk6bWVldGluZ19Zemt5WkdFME5tSXROMlk0WmkwME5tSmtMVGd4WXprdFpEbG1aR1kzT1RNMk1HUm1AdGhyZWFkLnYy","creationDateTime":"2026-01-05T02:42:32.1733565Z","startDateTime":"2026-01-05T03:00:00Z","endDateTime":"2026-01-05T03:30:00Z","joinUrl":"https://teams.microsoft.com/l/meetup-join/19%3ameeting_YzkyZGE0NmItN2Y4Zi00NmJkLTgxYzktZDlmZGY3OTM2MGRm%40thread.v2/0?context=%7b%22Tid%22%3a%2258970528-d083-476f-9082-2d21bd11a800%22%2c%22Oid%22%3a%22a52ac978-0df2-4e13-91e9-a1571eecde73%22%7d","meetingCode":"23004237007326","isBroadcast":false,"autoAdmittedUsers":"everyoneInCompany","outerMeetingAutoAdmittedUsers":null,"capabilities":[],"externalId":null,"meetingTemplateId":null,"meetingType":null,"meetingsMigrationMode":null,"joinWebUrl":"https://teams.microsoft.com/l/meetup-join/19%3ameeting_YzkyZGE0NmItN2Y4Zi00NmJkLTgxYzktZDlmZGY3OTM2MGRm%40thread.v2/0?context=%7b%22Tid%22%3a%2258970528-d083-476f-9082-2d21bd11a800%22%2c%22Oid%22%3a%22a52ac978-0df2-4e13-91e9-a1571eecde73%22%7d","subject":"定例会議","videoTeleconferenceId":null,"isEntryExitAnnounced":true,"isEndToEndEncryptionEnabled":false,"allowedPresenters":"everyone","allowAttendeeToEnableMic":true,"allowAttendeeToEnableCamera":true,"allowMeetingChat":"enabled","allowedLobbyAdmitters":"organizerAndCoOrganizersAndPresenters","shareMeetingChatHistoryDefault":"none","allowTeamworkReactions":true,"anonymizeIdentityForRoles":[],"recordAutomatically":false,"meetingSpokenLanguageTag":null,"allowParticipantsToChangeName":false,"allowTranscription":true,"allowRecording":true,"allowWhiteboard":true,"allowBreakoutRooms":true,"allowLiveShare":"enabled","allowPowerPointSharing":true,"allowCopyingAndSharingMeetingContent":true,"meetingOptionsWebUrl":"https://teams.microsoft.com/meetingOptions/?organizerId=a52ac978-0df2-4e13-91e9-a1571eecde73&tenantId=58970528-d083-476f-9082-2d21bd11a800&threadId=19_meeting_YzkyZGE0NmItN2Y4Zi00NmJkLTgxYzktZDlmZGY3OTM2MGRm@thread.v2&messageId=0&language=","iCalUid":"040000008200E00074C5B7101A82E00800000000654461F8EC7DDC010000000000000000100000009896E1BD5D1746479B614B4F7DAE7A25","expiryDateTime":"2026-03-06T03:30:00Z","broadcastSettings":null,"meetingInfo":null,"activeMeetingDetails":null,"sensitivityLabelAssignment":null,"chatRestrictions":null,"participants":{"organizer":{"upn":"hishida@MngEnvMCAP873995.onmicrosoft.com","role":"presenter","identity":{"application":null,"device":null,"user":{"id":"a52ac978-0df2-4e13-91e9-a1571eecde73","displayName":null,"tenantId":"58970528-d083-476f-9082-2d21bd11a800","identityProvider":"AAD"}}},"attendees":[]},"audioConferencing":{"conferenceId":"532984530","tollNumber":"+1 689-223-3502","tollFreeNumber":null,"dialinUrl":"https://dialin.teams.microsoft.com/7a636da7-907b-4107-8a92-0ff435c526db?id=532984530","tollNumbers":["+1 689-223-3502"],"tollFreeNumbers":[null]},"chatInfo":{"threadId":"19:meeting_YzkyZGE0NmItN2Y4Zi00NmJkLTgxYzktZDlmZGY3OTM2MGRm@thread.v2","messageId":"0","replyChainMessageId":null},"joinInformation":{"content":"data:text/html,%3cdiv+style%3d%22max-width%3a+1024px%3b+color%3a+%23242424%3b+font-family%3a%27Segoe+UI%27%2c%27Helvetica+Neue%27%2cHelvetica%2cArial%2csans-serif%22+class%3d%22me-email-text%22+lang%3d%22%22%3e%0a++%3cdiv+style%3d%22margin-bottom%3a24px%3boverflow%3ahidden%3bwhite-space%3anowrap%3b%22+aria-hidden%3d%22true%22%3e________________________________________________________________________________%3c%2fdiv%3e%0a%0a++%3cdiv+style%3d%22margin-bottom%3a+12px%3b%22%3e%0a++++%3cspan+class%3d%22me-email-text%22+style%3d%22font-size%3a+20px%3b+color%3a+%23242424%3b+font-weight%3a+600%22%3eMicrosoft+Teams+meeting%3c%2fspan%3e%0a++%3c%2fdiv%3e%0a%0a++%3cdiv+style%3d%22margin-bottom%3a+6px%3b+overflow-wrap%3a+break-word%3b%22%3e%0a++++%3cspan+class%3d%22me-email-text%22+style%3d%22font-size%3a+20px%3b+color%3a+%23242424%3b+fon ...
# Organizer:
#    hishida@MngEnvMCAP873995.onmicrosoft.com
# Attendees:
# GET https://graph.microsoft.com/v1.0/me/onlineMeetings/MSphNTJhYzk3OC0wZGYyLTRlMTMtOTFlOS1hMTU3MWVlY2RlNzMqMCoqMTk6bWVldGluZ19Zemt5WkdFME5tSXROMlk0WmkwME5tSmtMVGd4WXprdFpEbG1aR1kzT1RNMk1HUm1AdGhyZWFkLnYy/transcripts -> 200
# {"@odata.context":"https://graph.microsoft.com/v1.0/$metadata#users('a52ac978-0df2-4e13-91e9-a1571eecde73')/onlineMeetings('MSphNTJhYzk3OC0wZGYyLTRlMTMtOTFlOS1hMTU3MWVlY2RlNzMqMCoqMTk6bWVldGluZ19Zemt5WkdFME5tSXROMlk0WmkwME5tSmtMVGd4WXprdFpEbG1aR1kzT1RNMk1HUm1AdGhyZWFkLnYy')/transcripts","@odata.count":1,"value":[{"id":"ktVizInGAAAAi_B6lATZRTE5Om1lZXRpbmdfWXpreVpHRTBObUl0TjJZNFppMDBObUprTFRneFl6a3RaRGxtWkdZM09UTTJNR1JtQHRocmVhZC52MqEw2TwwNTE1MmEyNy1mNWQ5LTRjNTMtODUzNC0wOThlYmIxNjQ4ZjMtMTc2NzU4MDk5OS1UcmFuc2NyaXB0VjI=","meetingId":"MSphNTJhYzk3OC0wZGYyLTRlMTMtOTFlOS1hMTU3MWVlY2RlNzMqMCoqMTk6bWVldGluZ19Zemt5WkdFME5tSXROMlk0WmkwME5tSmtMVGd4WXprdFpEbG1aR1kzT1RNMk1HUm1AdGhyZWFkLnYy","callId":"05152a27-f5d9-4c53-8534-098ebb1648f3","contentCorrelationId":"278a0c45-c1c4-4f73-aadd-6e3e5590ed17-20260105_024319","transcriptContentUrl":"https://graph.microsoft.com/v1.0/users/a52ac978-0df2-4e13-91e9-a1571eecde73/onlineMeetings/MSphNTJhYzk3OC0wZGYyLTRlMTMtOTFlOS1hMTU3MWVlY2RlNzMqMCoqMTk6bWVldGluZ19Zemt5WkdFME5tSXROMlk0WmkwME5tSmtMVGd4WXprdFpEbG1aR1kzT1RNMk1HUm1AdGhyZWFkLnYy/transcripts/ktVizInGAAAAi_B6lATZRTE5Om1lZXRpbmdfWXpreVpHRTBObUl0TjJZNFppMDBObUprTFRneFl6a3RaRGxtWkdZM09UTTJNR1JtQHRocmVhZC52MqEw2TwwNTE1MmEyNy1mNWQ5LTRjNTMtODUzNC0wOThlYmIxNjQ4ZjMtMTc2NzU4MDk5OS1UcmFuc2NyaXB0VjI=/content","createdDateTime":"2026-01-05T02:43:19.4511092Z","endDateTime":"2026-01-05T02:48:47.0511092Z","meetingOrganizer":{"application":null,"device":null,"user":{"@odata.type":"#microsoft.graph.teamworkUserIdentity","id":"a52ac978-0df2-4e13-91e9-a1571eecde73","displayName":null,"userIdentityType":"aadUser","tenantId":"58970528-d083-476f-9082-2d21bd11a800"}}}]}
# Transcript id= ktVizInGAAAAi_B6lATZRTE5Om1lZXRpbmdfWXpreVpHRTBObUl0TjJZNFppMDBObUprTFRneFl6a3RaRGxtWkdZM09UTTJNR1JtQHRocmVhZC52MqEw2TwwNTE1MmEyNy1mNWQ5LTRjNTMtODUzNC0wOThlYmIxNjQ4ZjMtMTc2NzU4MDk5OS1UcmFuc2NyaXB0VjI= | created= 2026-01-05T02:43:19.4511092Z
# GET https://graph.microsoft.com/v1.0/me/onlineMeetings/MSphNTJhYzk3OC0wZGYyLTRlMTMtOTFlOS1hMTU3MWVlY2RlNzMqMCoqMTk6bWVldGluZ19Zemt5WkdFME5tSXROMlk0WmkwME5tSmtMVGd4WXprdFpEbG1aR1kzT1RNMk1HUm1AdGhyZWFkLnYy/transcripts/ktVizInGAAAAi_B6lATZRTE5Om1lZXRpbmdfWXpreVpHRTBObUl0TjJZNFppMDBObUprTFRneFl6a3RaRGxtWkdZM09UTTJNR1JtQHRocmVhZC52MqEw2TwwNTE1MmEyNy1mNWQ5LTRjNTMtODUzNC0wOThlYmIxNjQ4ZjMtMTc2NzU4MDk5OS1UcmFuc2NyaXB0VjI=/content?%24format=text%2Fvtt -> 200
# WEBVTT
#
# 00:00:15.445 --> 00:00:33.645
# <v Hiroaki Ishida>ã¯ãããç²ãæ§ã§ãããããä¼è­°ã®æ¹ãå§ãããã¦ããã ãããã¨æãã¾ãããããããé¡ããããã¾ããããããä»æ¥ã®è­°é¡ã¯ããã£ã¨ãåé±ãç¸è«ãããã ãã¦ããããã£ã¨ãAIãæ´»ç¨ãã¦ããããã®ãã¼ã¿ãã¼ã¹ã®è¨­å®ã£ã¦ããã¨ããã§ã</v>
#
# 00:00:33.805 --> 00:00:50.445
# <v Hiroaki Ishida>ãã£ã¨ãã¾ããããã¤ãããã®ç¾ç¶ã®ãã
# Saved transcript content to meeting_transcript_0.vtt
# GET https://graph.microsoft.com/v1.0/chats/19:meeting_YzkyZGE0NmItN2Y4Zi00NmJkLTgxYzktZDlmZGY3OTM2MGRm@thread.v2/messages
#   -> 200
# {"@odata.context":"https://graph.microsoft.com/v1.0/$metadata#chats('19%3Ameeting_YzkyZGE0NmItN2Y4Zi00NmJkLTgxYzktZDlmZGY3OTM2MGRm%40thread.v2')/messages","@odata.count":8,"value":[{"id":"1767581367339","replyToId":null,"etag":"1767581368468","messageType":"unknownFutureValue","createdDateTime":"2026-01-05T02:49:27.339Z","lastModifiedDateTime":"2026-01-05T02:49:28.468Z","lastEditedDateTime":null,"deletedDateTime":null,"subject":null,"summary":null,"chatId":"19:meeting_YzkyZGE0NmItN2Y4Zi00NmJkLTgxYzktZDlmZGY3OTM2MGRm@thread.v2","importance":"normal","locale":"en-us","webUrl":null,"from":null,"channelIdentity":null,"policyViolation":null,"body":{"contentType":"html","content":"<systemEventMessage/>"},"attachments":[],"mentions":[],"reactions":[],"eventDetail":{"@odata.type":"#microsoft.graph.callRecordingEventMessageDetail","callId":"05152a27-f5d9-4c53-8534-098ebb1648f3","callRecordingDisplayName":"定例会議-20260105_114312-会議の録音.mp4","callRecordingUrl":"https://mngenvmcap873995-my.sharepoint.com/:v:/g/personal/hishida_mngenvmcap873995_onmicrosoft_com/IQB3ff9QX1EwRpyNlw8YoaKfAbTSQIwuNxAy8OY_0KoRaLo","callRecordingDuration":"PT5M27.6S","callRecordingStatus":"success","meetingOrganizer":{"application":null,"device":null,"user":{"@odata.type":"#microsoft.graph.teamworkUserIdentity","id":"a52ac978-0df2-4e13-91e9-a1571eecde73","displayName":null,"userIdentityType":"aadUser","tenantId":"58970528-d083-476f-9082-2d21bd11a800"}},"initiator":{"application":null,"device":null,"user":{"@odata.type":"#microsoft.graph.teamworkUserIdentity","id":"a52ac978-0df2-4e13-91e9-a1571eecde73","displayName":null,"userIdentityType":"aadUser","tenantId":"58970528-d083-476f-9082-2d21bd11a800"}}}},{"id":"1767581322186","replyToId":null,"etag":"1767581322186","messageType":"unknownFutureValue","createdDateTime":"2026-01-05T02:48:42.186Z","lastModifiedDateTime":"2026-01-05T02:48:42.186Z","lastEditedDateTime":null,"deletedDateTime":null,"subject":null,"summary":null,"chatId":"19:meeting_YzkyZGE0NmItN2Y4Zi00NmJkLTgxYzktZDlmZGY3OTM2MGRm@thread.v2","importance":"normal","locale":"en-us","webUrl":null,"from":null,"channelIdentity":null,"policyViolation":null,"body":{"contentType":"html","content":"<systemEventMessage/>"},"attachments":[],"mentions":[],"reactions":[],"eventDetail":{"@odata.type":"#microsoft.graph.callRecordingEventMessageDetail","callId":"05152a27-f5d9-4c53-8534-098ebb1648f3","callRecordingDisplayName":"定例会議-20260105_024314UTC-Meeting Recording.mp4","callRecordingUrl":"https://graph.microsoft.com/v1.0/chats/19:meeting_YzkyZGE0NmItN2Y4Zi00NmJkLTgxYzktZDlmZGY3OTM2MGRm@thread./$value","callRecordingDuration":"PT5M27.6S","callRecordingStatus":"chunkFinished","meetingOrganizer":{"application":null,"device":null,"user":{"@odata.type":"#microsoft.graph.teamworkUserIdentity","id":"a52ac978-0df2-4e13-91e9-a1571eecde73","displayName":null,"userIdentityType":"aadUser","tenantId":"58970528-d083-476f-9082-2d21bd11a800"}},"initiator":{"application":null,"device":null,"user":{"@odata.type":"#microsoft.graph.teamworkUserIdentity","id":"a52ac978-0df2-4e13-91e9-a1571eecde73","displayName":null,"userIdentityType":"aadUser","tenantId":"58970528-d083-476f-9082-2d21bd11a800"}}}},{"id":"1767581320210","replyToId":null,"etag":"1767581320210","messageType":"unknownFutureValue","createdDateTime":"2026-01-05T02:48:40.21Z","lastModifiedDateTime":"2026-01-05T02:48:40.21Z","lastEditedDateTime":null,"deletedDateTime":null,"subject":null,"summary":null,"chatId":"19:meeting_YzkyZGE0NmItN2Y4Zi00NmJkLTgxYzktZDlmZGY3OTM2MGRm@thread.v2","importance":"normal","locale":"en-us","webUrl":null,"from":null,"channelIdentity":null,"policyViolation":null,"body":{"contentType":"html","content":"<systemEventMessage/>"},"attachments":[],"men ...
